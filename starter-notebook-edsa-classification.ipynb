# %% [markdown]
# ## Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import nltk
import string
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

from sklearn.metrics import f1_score

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load in your data from kaggle.
# By working in a kaggle kernel, you can access the data directly from the competition, as well as make your submission without downloading your output file

# %%
train = pd.read_csv('../input/climate-change-edsa2020-21/train.csv')
test = pd.read_csv('../input/climate-change-edsa2020-21/test.csv')

# %%
train.sentiment.value_counts()
# Out:
#  1    8530
#  2    3640
#  0    2353
# -1    1296
# Name: sentiment, dtype: int64

# %% [markdown]
# ## Splitting out the X variable from the target

# %%
y = train['sentiment']
X = train['message']

# %%
from nltk.stem import PorterStemmer

# init stemmer
porter_stemmer=PorterStemmer()

def my_cool_preprocessor(text):
    
    text=text.lower() 
    text=re.sub("\\W"," ",text) # remove special chars
    text=re.sub("\\s+(in|the|all|for|and|on)\\s+"," _connector_ ",text) # normalize certain words
    
    # stem words
    words=re.split("\\s+",text)
    stemmed_words=[porter_stemmer.stem(word=word) for word in words]
    return ' '.join(stemmed_words)

# %%
def my_tokenizer(text):
    # create a space between special characters 
    text=re.sub("(\\W)"," \\1 ",text)

    # split based on whitespace
    return re.split("\\s+",text)

# %% [markdown]
# ## Turning text into something your model can read

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,2),tokenizer=my_tokenizer, min_df=2,stop_words=["all","in","the","is","and"])
X_vectorized = vectorizer.fit_transform(X)
, 
#stop_words="english",max_df=0.85, preprocessor=my_cool_preprocessor,
# Out:
# ''

# %%
vectorizer.vocabulary_
# Out:
# {'epa': 15093,
#  'chief': 11392,
#  'doesn': 14143,
#  "'": 541,
#  't': 31811,
#  'think': 32868,
#  'carbon': 10328,
#  'dioxide': 13840,
#  'main': 22129,
#  'cause': 10470,
#  'of': 24507,
#  'global': 17312,
#  'warming': 35610,
#  '.': 1906,
#  'wait': 35496,
#  ',': 1034,
#  'what': 36362,
#  '!': 16,
#  '?': 4285,
#  'https': 19049,
#  ':': 3215,
#  '/': 2386,
#  'co': 11937,
#  'via': 35288,
#  '@': 4411,
#  'mashable': 22394,
#  'epa chief': 15112,
#  'chief doesn': 11399,
#  "doesn '": 14144,
#  "' t": 821,
#  't think': 31939,
#  'think carbon': 32879,
#  'carbon dioxide': 10333,
#  'dioxide main': 13849,
#  'main cause': 22130,
#  'cause of': 10482,
#  'of global': 24646,
#  'global warming': 17346,
#  'warming .': 35619,
#  '. .': 1917,
#  '. wait': 2342,
#  'wait ,': 35497,
#  ', what': 1593,
#  'what !': 36363,
#  '! ?': 28,
#  '? https': 4335,
#  'https :': 19050,
#  ': /': 3226,
#  '/ /': 2390,
#  '/ t': 2581,
#  't .': 31815,
#  '. co': 2000,
#  'co /': 11941,
#  'via @': 35291,
#  '@ mashable': 5199,
#  'it': 20140,
#  's': 28875,
#  'not': 24049,
#  'like': 21620,
#  'we': 36076,
#  'lack': 21102,
#  'evidence': 15383,
#  'anthropogenic': 7620,
#  "it '": 20144,
#  "' s": 794,
#  's not': 29121,
#  'not like': 24121,
#  'like we': 21663,
#  'evidence of': 15393,
#  'of anthropogenic': 24537,
#  'anthropogenic global': 7622,
#  'rt': 28791,
#  'rawstory': 27636,
#  'researchers': 28360,
#  'say': 29469,
#  'have': 18159,
#  'three': 33163,
#  'years': 37506,
#  'to': 33305,
#  'act': 6540,
#  'on': 25000,
#  'climate': 11722,
#  'change': 10656,
#  'before': 8927,
#  '’': 38220,
#  'too': 33980,
#  'late': 21181,
#  '…': 38324,
#  '': 0,
#  'rt @': 28795,
#  '@ rawstory': 5444,
#  'rawstory :': 27637,
#  ': researchers': 3897,
#  'researchers say': 28367,
#  'say we': 29498,
#  'we have': 36132,
#  'have three': 18226,
#  'three years': 33166,
#  'years to': 37526,
#  'to act': 33331,
#  'act on': 6547,
#  'on climate': 25038,
#  'climate change': 11737,
#  'change before': 10742,
#  'before it': 8939,
#  'it ’': 20290,
#  '’ s': 38244,
#  's too': 29228,
#  'too late': 33992,
#  'late https': 21185,
#  '… ': 38325,
#  '#': 92,
#  'wired': 36908,
#  '2016': 2854,
#  'was': 35887,
#  'a': 5839,
#  'pivotal': 26313,
#  'year': 37481,
#  'war': 35578,
#  ' #': 1,
#  '# wired': 480,
#  'wired :': 36909,
#  ': 2016': 3246,
#  '2016 was': 2863,
#  'was a': 35892,
#  'a pivotal': 6111,
#  'pivotal year': 26314,
#  'year war': 37502,
#  'war on': 35591,
#  'change https': 10958,
#  'racist': 27536,
#  'sexist': 30179,
#  'denying': 13596,
#  'bigot': 9261,
#  'leading': 21315,
#  'polls': 26636,
#  'electionnight': 14753,
#  ': it': 3651,
#  's 2016': 28885,
#  '2016 ,': 2857,
#  ', a': 1060,
#  'a racist': 6139,
#  'racist ,': 27537,
#  ', sexist': 1493,
#  'sexist ,': 30180,
#  ', climate': 1147,
#  'change denying': 10832,
#  'denying bigot': 13600,
#  'bigot leading': 9262,
#  'leading polls': 21325,
#  'polls .': 26637,
#  '. #': 1909,
#  '# electionnight': 239,
#  'worth': 37309,
#  'read': 27709,
#  'whether': 36497,
#  'you': 37593,
#  'do': 14028,
#  'or': 25355,
#  'don': 14184,
#  'believe': 9035,
#  'worth a': 37311,
#  'a read': 6142,
#  'whether you': 36506,
#  'you do': 37631,
#  'do or': 14050,
#  'or don': 25370,
#  "don '": 14185,
#  't believe': 31839,
#  'believe climate': 9046,
#  'thenation': 32663,
#  'mike': 22842,
#  'pence': 26018,
#  'that': 32367,
#  'smoking': 30672,
#  'causes': 10493,
#  'cancer': 10295,
#  '@ thenation': 5671,
#  'thenation :': 32664,
#  ': mike': 3738,
#  'mike pence': 22844,
#  'pence doesn': 26020,
#  'doesn ’': 14145,
#  '’ t': 38245,
#  'believe global': 9052,
#  'warming or': 35753,
#  'or that': 25390,
#  'cancer .': 10297,
#  '. https': 2111,
#  'six': 30550,
#  'big': 9208,
#  'things': 32855,
#  'can': 10178,
#  'today': 33890,
#  'fight': 16043,
#  'how': 18958,
#  'be': 8689,
#  '¢': 37966,
#  'â': 38035,
#  '‚': 38256,
#  '¬': 37996,
#  '¦': 37989,
#  'hã': 19195,
#  ': six': 3954,
#  'things we': 32866,
#  'we can': 36101,
#  'can do': 10200,
#  'do today': 14066,
#  'today to': 33907,
#  'to fight': 33517,
#  'fight climate': 16050,
#  'change ,': 10664,
#  ', or': 1410,
#  'or how': 25377,
#  'how to': 19018,
#  'to be': 33368,
#  'be a': 8695,
#  'a climate': 5906,
#  '¢ â': 37977,
#  'â ‚': 38047,
#  '‚ ¬': 38260,
#  '¬ â': 37998,
#  'â ¦': 38041,
#  '¦ https': 37991,
#  'hã ¢': 19196,
#  '¦ ': 37990,
#  'aceofspadeshq': 6510,
#  'my': 23370,
#  'he': 18270,
#  'wants': 35567,
#  'die': 13795,
#  'old': 24977,
#  'age': 6905,
#  'me': 22514,
#  'but': 9845,
#  'will': 36730,
#  ' @': 7,
#  '@ aceofspadeshq': 4437,
#  '. he': 2092,
#  'he wants': 18322,
#  'wants to': 35574,
#  'to die': 33461,
#  'die of': 13803,
#  'of old': 24738,
#  'old age': 24980,
#  'like me': 21645,
#  'me ,': 22520,
#  ', but': 1125,
#  'but will': 9924,
#  'of climate': 24571,
#  'change .': 10666,
#  '. ': 1907,
#  'no': 23919,
#  'offense': 24887,
#  'just': 20656,
#  ': no': 3774,
#  'no offense': 23956,
#  '… but': 38330,
#  'but like': 9880,
#  'like …': 21666,
#  'how do': 18982,
#  'do you': 14075,
#  'you just': 37672,
#  'just not': 20716,
#  'not believe': 24072,
#  'believe …': 9072,
#  'warming …': 35839,
#  '… …': 38336,
#  'stephenschlegel': 31298,
#  'she': 30220,
#  'thinking': 32909,
#  'about': 6331,
#  'going': 17452,
#  'because': 8840,
#  'your': 37751,
#  'husband': 19166,
#  'sjofonã': 30558,
#  '@ stephenschlegel': 5610,
#  'stephenschlegel :': 31299,
#  ': she': 3943,
#  "she '": 30221,
#  's thinking': 29222,
#  'thinking about': 32910,
#  'about how': 6364,
#  'how she': 19010,
#  's going': 29035,
#  'going to': 17460,
#  'die because': 13799,
#  'because your': 8864,
#  'your husband': 37775,
#  'husband doesn': 19167,
#  '/ sjofonã': 2577,
#  'sjofonã ¢': 30559,
#  'i': 19197,
#  'hope': 18856,
#  'people': 26040,
#  'who': 36566,
#  'are': 7792,
#  'also': 7220,
#  'their': 32593,
#  'homes': 18823,
#  'with': 36931,
#  'renewable': 28231,
#  'energy': 14927,
#  'goodenergy': 17519,
#  'i do': 19228,
#  'people who': 26101,
#  'who are': 36570,
#  'about climate': 6349,
#  'change also': 10715,
#  'homes with': 18825,
#  'renewable energy': 28232,
#  'energy ,': 14932,
#  ', like': 1344,
#  'like @': 21627,
#  '@ goodenergy': 4918,
#  'tveitdal': 34535,
#  'only': 25250,
#  '5': 3035,
#  'percent': 26117,
#  'chance': 10649,
#  'avoiding': 8432,
#  '‘': 38196,
#  'dangerous': 13059,
#  'study': 31492,
#  'finds': 16132,
#  '@ tveitdal': 5717,
#  'tveitdal :': 34536,
#  ': we': 4088,
#  'we only': 36157,
#  'only have': 25267,
#  'have a': 18163,
#  'a 5': 5853,
#  '5 percent': 3043,
#  'percent chance': 26118,
#  'chance of': 10651,
#  'of avoiding': 24545,
#  'avoiding ‘': 8434,
#  '‘ dangerous': 38201,
#  'dangerous ’': 13067,
#  '’ global': 38235,
#  'warming ,': 35617,
#  'a study': 6204,
#  'study finds': 31498,
#  'finds https': 16134,
#  'of …': 24863,
#  'oh': 24925,
#  'god': 17428,
#  'trump': 34251,
#  'government': 17590,
#  'removes': 28222,
#  'page': 25772,
#  'from': 16790,
#  'website': 36260,
#  'hours': 18927,
#  'ahead': 7024,
#  'climatemarch': 11828,
#  ': oh': 3794,
#  'oh .': 24928,
#  '. my': 2185,
#  'my .': 23373,
#  '. god': 2075,
#  'god .': 17431,
#  '. trump': 2325,
#  "trump '": 34255,
#  's government': 29040,
#  'removes climate': 28223,
#  'change page': 11064,
#  'page from': 25777,
#  'from epa': 16815,
#  'epa website': 15145,
#  'website hours': 36267,
#  'hours ahead': 18928,
#  'ahead of': 7026,
#  'of #': 24508,
#  '# climatemarch': 179,
#  'climatemarch https': 11830,
#  'fossil': 16644,
#  'fuel': 16930,
#  'giant': 17249,
#  'exxonmobil': 15664,
#  'misled': 22958,
#  'public': 27316,
#  'harvard': 18044,
#  'academics': 6440,
#  'conclude': 12270,
#  'fossil fuel': 16646,
#  'public about': 27320,
#  ', harvard': 1275,
#  'glblctzn': 17306,
#  'wanna': 35538,
#  'live': 21762,
#  'forever': 16621,
#  '–': 38146,
#  'nothing': 24188,
#  '�': 38396,
#  '️': 38389,
#  '@ glblctzn': 4907,
#  'glblctzn :': 17307,
#  ": '": 3220,
#  "' i": 697,
#  'i don': 19229,
#  't wanna': 31948,
#  'nothing will': 24197,
#  'because climate': 8844,
#  "change '": 10660,
#  "' �": 899,
#  '� �': 38411,
#  '� ️': 38410,
#  '️ �': 38395,
#  '� @': 38402,
#  'issues': 20121,
#  'scrubbed': 29858,
#  'civil': 11618,
#  'rights': 28607,
#  'lgbt': 21524,
#  'healthcare': 18383,
#  ': issues': 3650,
#  'scrubbed from': 29859,
#  'from https': 16832,
#  'today :': 33897,
#  'civil rights': 11619,
#  'rights ,': 28609,
#  ', lgbt': 1339,
#  'lgbt ,': 21526,
#  ', healthcare': 1283,
#  'patagonia': 25929,
#  'if': 19396,
#  'our': 25486,
#  'elected': 14727,
#  'leaders': 21285,
#  'fail': 15771,
#  'approach': 7739,
#  'environment': 15042,
#  '&': 537,
#  'amp': 7394,
#  ';': 4140,
#  'as': 8068,
#  'serious': 30113,
#  'worthy': 37313,
#  'urgency': 34976,
#  'action': 6555,
#  'wiã': 37044,
#  '@ patagonia': 5366,
#  'patagonia :': 25930,
#  ': if': 3622,
#  'if our': 19430,
#  'our elected': 25508,
#  'elected leaders': 14733,
#  'leaders fail': 21294,
#  'fail to': 15773,
#  'to approach': 33353,
#  'approach environment': 7740,
#  'environment &': 15045,
#  '& amp': 538,
#  'amp ;': 7395,
#  '; climate': 4164,
#  'change as': 10727,
#  'as serious': 8128,
#  'serious issues': 30120,
#  'issues worthy': 20136,
#  'worthy of': 37314,
#  'of urgency': 24833,
#  'urgency &': 34977,
#  '; action': 4154,
#  'action ,': 6559,
#  ', it': 1320,
#  'it wiã': 20283,
#  'wiã ¢': 37045,
#  'sensanders': 30073,
#  'president': 26880,
#  '-': 1630,
#  'elect': 14714,
#  'millions': 22887,
#  'mr': 23268,
#  'tã': 34585,
#  '@ sensanders': 5569,
#  'sensanders :': 30074,
#  'a president': 6125,
#  'president -': 26884,
#  '- elect': 1735,
#  'elect who': 14726,
#  'who doesn': 36589,
#  '. millions': 2179,
#  'millions of': 22891,
#  'of people': 24746,
#  'people are': 26052,
#  'are going': 7863,
#  'to have': 33552,
#  'have to': 18229,
#  'to say': 33751,
#  'say :': 29474,
#  ': mr': 3748,
#  'mr .': 23269,
#  '. tã': 2328,
#  'tã ¢': 34586,
#  '*': 1007,
#  'tweets': 34548,
#  'abt': 6433,
#  'w': 35481,
#  'sees': 30015,
#  'replies': 28256,
#  'begging': 8964,
#  'him': 18639,
#  'come': 12093,
#  'countries': 12683,
#  'goes': 17443,
#  'back': 8492,
#  ': *': 3223,
#  'him to': 18652,
#  'to come': 33416,
#  'come to': 12106,
#  'to their': 33819,
#  'countries -': 12686,
#  'goes back': 17444,
#  'back to': 8515,
#  'change *': 10663,
#  '* ': 1008,
#  'c40cities': 10067,
#  '46': 3018,
#  'c40': 10066,
#  'mayors': 22498,
#  'representing': 28290,
#  'citizens': 11594,
#  'urged': 34972,
#  'g20': 17023,
#  '@ c40cities': 4609,
#  'c40cities :': 10069,
#  'g20 leaders': 17025,
#  'leaders to': 21305,
#  'to #': 33306,
#  'from climate': 16807,
#  '. you': 2372,
#  'you can': 37620,
#  'can too': 10249,
#  'too …': 33996,
#  'world_wildlife': 37245,
#  'impacts': 19570,
#  'wildlife': 36722,
#  'oztap4cdlk': 25728,
#  'cop22': 12536,
#  'earthtomarrakech': 14532,
#  'xm5xgpvhqy': 37430,
#  '@ world_wildlife': 5776,
#  'world_wildlife :': 37246,
#  ': how': 3605,
#  'how climate': 18975,
#  'change impacts': 10972,
#  'impacts wildlife': 19577,
#  'wildlife :': 36725,
#  ': https': 3608,
#  '/ oztap4cdlk': 2548,
#  'oztap4cdlk #': 25729,
#  '# cop22': 196,
#  'cop22 #': 12537,
#  '# earthtomarrakech': 233,
#  'earthtomarrakech https': 14534,
#  '/ xm5xgpvhqy': 2620,
#  'met': 22747,
#  'this': 32938,
#  'guy': 17867,
#  'let': 21468,
#  'us': 35000,
#  'some': 30850,
#  'truth': 34460,
#  'gay': 17101,
#  'existing': 15485,
#  'we also': 36088,
#  'this guy': 32991,
#  ', he': 1280,
#  'let us': 21477,
#  'us on': 35065,
#  'on some': 25152,
#  'truth about': 34466,
#  'change gay': 10916,
#  'gay people': 17105,
#  'people not': 26079,
#  'scientists': 29756,
#  'wiped': 36904,
#  'out': 25575,
#  'an': 7412,
#  'entire': 15014,
#  'underwater': 34762,
#  'ecosystem': 14612,
#  'again': 6873,
#  'climateã': 11857,
#  'scientists say': 29800,
#  'say climate': 29478,
#  'wiped out': 36905,
#  'out an': 25585,
#  'an entire': 7446,
#  'underwater ecosystem': 34765,
#  '. again': 1944,
#  'again .': 6877,
#  '# climateã': 187,
#  'climateã ¢': 11858,
#  'obama': 24403,
#  'raises': 27568,
#  'better': 9163,
#  'vote': 35412,
#  'for': 16372,
#  'candidates': 10304,
#  'science': 29651,
#  ': obama': 3787,
#  'you better': 37618,
#  'vote for': 35419,
#  'who believe': 36572,
#  'believe science': 9065,
#  'science .': 29658,
#  'hate': 18142,
#  'mental': 22698,
#  'health': 18365,
#  'pretty': 26940,
#  'low': 21986,
#  'menu': 22714,
#  'when': 36437,
#  'hits': 18732,
#  'food': 16339,
#  'production': 27071,
#  'i hate': 19241,
#  'say this': 29496,
#  'this ,': 32943,
#  'will be': 36746,
#  'be pretty': 8776,
#  'on menu': 25110,
#  ', when': 1594,
#  'when climate': 36446,
#  'change hits': 10951,
#  'food production': 16344,
#  'an …': 7494,
#  '… https': 38334,
#  'bangladesh': 8587,
#  'confronting': 12314,
#  'head': 18330,
#  'change head': 10941,
#  'head on': 18344,
#  'on https': 25086,
#  'hey': 18553,
#  'there': 32682,
#  'michael': 22782,
#  'approved': 7749,
#  'market': 22349,
#  'based': 8633,
#  'strategies': 31438,
#  'tackling': 31967,
#  'supported': 31670,
#  'by': 9948,
#  'majority': 22162,
#  'cdns': 10554,
#  'cdnpoli': 10551,
#  'hey there': 18561,
#  'there !': 32683,
#  '! michael': 62,
#  'market -': 22350,
#  '- based': 1667,
#  'for tackling': 16545,
#  'tackling climate': 31969,
#  'change are': 10724,
#  'supported by': 31671,
#  'by a': 9965,
#  'a majority': 6064,
#  'majority of': 22163,
#  '! #': 19,
#  '# cdnpoli': 154,
#  'sally': 29328,
#  'kohn': 21055,
#  'latest': 21192,
#  'proves': 27247,
#  'smart': 30653,
#  'person': 26158,
#  'twitchyteam': 34560,
#  'need': 23630,
#  'more': 23110,
#  'sally kohn': 29329,
#  'kohn ’': 21056,
#  's latest': 29086,
#  'latest evidence': 21195,
#  'change proves': 11103,
#  'proves she': 27250,
#  'she ‘': 30229,
#  '‘ not': 38207,
#  'not a': 24058,
#  'a smart': 6189,
#  'smart person': 30655,
#  'person ’': 26163,
#  '’ https': 38236,
#  '@ twitchyteam': 5718,
#  'we say': 36166,
#  'first': 16160,
#  'understands': 34756,
#  'than': 32313,
#  'congress': 12324,
#  'why': 36647,
#  'corybooker': 12596,
#  'neiltyson': 23679,
#  'explain': 15549,
#  'htt': 19044,
#  ': first': 3519,
#  ': public': 3863,
#  'understands climate': 34757,
#  'change better': 10747,
#  'better than': 9170,
#  '. why': 2358,
#  'why ?': 36652,
#  '? #': 4288,
#  '@ corybooker': 4721,
#  '@ neiltyson': 5290,
#  'htt …': 19045,
#  'these': 32734,
#  'same': 29342,
#  'denounce': 13584,
#  'choice': 11503,
#  'are these': 7955,
#  'these same': 32751,
#  'same scientists': 29350,
#  'scientists that': 29806,
#  'denounce climate': 13585,
#  'change ?': 10677,
#  '? it': 4342,
#  'a choice': 5899,
#  'guide': 17838,
#  'paris': 25844,
#  'pact': 25763,
#  'role': 28742,
#  'demforce': 13465,
#  'theresistance': 32723,
#  'uniteblue': 34816,
#  ': a': 3270,
#  'a guide': 6009,
#  'guide to': 17840,
#  'to global': 33538,
#  ', paris': 1417,
#  'paris pact': 25853,
#  '# demforce': 213,
#  '# theresistance': 439,
#  'theresistance #': 32724,
#  '# uniteblue': 461,
#  'latimes': 21199,
#  'atmospheric': 8331,
#  'rivers': 28679,
#  'fueled': 16934,
#  'could': 12615,
#  'decimate': 13300,
#  'wild': 36714,
#  'oysters': 25725,
#  'san': 29363,
#  'francisco': 16701,
#  'bay': 8660,
#  '@ latimes': 5140,
#  'latimes :': 21200,
#  'atmospheric rivers': 8332,
#  'rivers fueled': 28681,
#  'fueled by': 16935,
#  'by climate': 9977,
#  'change could': 10807,
#  'could decimate': 12627,
#  'decimate wild': 13301,
#  'wild oysters': 36715,
#  'oysters san': 25726,
#  'san francisco': 29365,
#  'francisco bay': 16702,
#  'bay https': 8662,
#  't …': 31954,
#  'ignores': 19484,
#  'basic': 8637,
#  'denying climate': 13602,
#  '~': 37922,
#  'china': 11437,
#  'practically': 26801,
#  'says': 29515,
#  'lied': 21580,
#  'says trump': 29556,
#  'lied about': 21581,
#  'berniesanders': 9132,
#  'imvotingbecause': 19625,
#  'future': 16994,
#  'planet': 26350,
#  'at': 8240,
#  'stake': 31131,
#  'hillary': 18622,
#  'clinton': 11863,
#  'combat': 12078,
#  'donald': 14187,
#  'thinks': 32916,
#  'iã': 20352,
#  '@ berniesanders': 4559,
#  'berniesanders :': 9133,
#  ': #': 3217,
#  '# imvotingbecause': 308,
#  'imvotingbecause future': 19626,
#  'future of': 17004,
#  'of planet': 24749,
#  'planet at': 26359,
#  'at stake': 8303,
#  'stake .': 31132,
#  '. hillary': 2100,
#  'hillary clinton': 18626,
#  'clinton will': 11871,
#  'will combat': 36760,
#  'combat climate': 12081,
#  '. donald': 2027,
#  'donald trump': 14193,
#  'trump thinks': 34410,
#  'thinks iã': 32925,
#  'iã ¢': 20353,
#  'independent': 19688,
#  'team': 32131,
#  'removed': 28217,
#  'data': 13102,
#  'white': 36555,
#  'house': 18930,
#  'they': 32762,
#  'may': 22447,
#  'breaking': 9612,
#  'law': 21221,
#  '@ independent': 4993,
#  'independent :': 19689,
#  ': trump': 4039,
#  's team': 29212,
#  'removed climate': 28219,
#  'change data': 10820,
#  'data from': 13113,
#  'from white': 16878,
#  'white house': 36557,
#  'house website': 18946,
#  'website .': 36264,
#  '. they': 2310,
#  'they may': 32799,
#  'may be': 22453,
#  'be breaking': 8711,
#  'law …': 21225,
#  'toxic': 34073,
#  'soils': 30797,
#  'vast': 35207,
#  'wasted': 35970,
#  '(': 902,
#  '+': 1029,
#  'waste': 35965,
#  ')': 965,
#  'water': 36010,
#  'runaway': 28830,
#  'part': 25885,
#  'gas': 17069,
#  'fracking': 16680,
#  '( +': 909,
#  ') water': 1001,
#  'water ,': 36013,
#  ', runaway': 1473,
#  'runaway climate': 28831,
#  'change -': 10665,
#  '- what': 1890,
#  'part of': 25889,
#  "' …": 898,
#  'america': 7310,
#  'where': 36477,
#  '“': 38262,
#  'unproven': 34857,
#  '”': 38293,
#  '100': 2684,
#  '%': 520,
#  'sure': 31692,
#  'called': 10124,
#  'noah': 23993,
#  'fit': 16197,
#  'world': 37177,
#  'animals': 7541,
#  'hi': 18567,
#  ': america': 3289,
#  'america :': 7317,
#  ': where': 4095,
#  'where climate': 36481,
#  'change “': 11278,
#  '” to': 38310,
#  'to people': 33675,
#  '100 %': 2685,
#  '% sure': 535,
#  'a guy': 6010,
#  "world '": 37182,
#  'hi …': 18572,
#  've': 35215,
#  'simple': 30488,
#  'policy': 26560,
#  'now': 24223,
#  'complex': 12224,
#  'mal': 22219,
#  'vs': 35466,
#  'tones': 33962,
#  'qanda': 27418,
#  'we ’': 36196,
#  '’ ve': 38247,
#  'issues like': 20130,
#  'like climate': 21634,
#  'change energy': 10866,
#  'energy policy': 14949,
#  'policy .': 26565,
#  '. now': 2199,
#  'issues .': 20124,
#  '# qanda': 384,
#  'support': 31654,
#  'then': 32640,
#  'did': 13771,
#  'help': 18455,
#  ': they': 4011,
#  'support of': 31666,
#  'change at': 10730,
#  'at #': 8241,
#  'their part': 32608,
#  'part to': 25890,
#  'to help': 33559,
#  'help environment': 18466,
#  'environment .': 15047,
#  '/ …': 2633,
#  '2050': 2888,
#  'targets': 32081,
#  'nations': 23563,
#  'playing': 26431,
#  'long': 21863,
#  'game': 17053,
#  'fighting': 16061,
#  'conversationedu': 12487,
#  ': nations': 3758,
#  'nations are': 23565,
#  'are playing': 7918,
#  'fighting global': 16067,
#  'warming https': 35710,
#  '@ conversationedu': 4713,
#  'thedailybeast': 32568,
#  'denial': 13490,
#  'cost': 12598,
#  '$': 496,
#  'trillion': 34200,
#  '@ thedailybeast': 5657,
#  'thedailybeast :': 32569,
#  's climate': 28961,
#  'change denial': 10826,
#  'denial could': 13498,
#  'could cost': 12625,
#  'cost us': 12603,
#  'us $': 35003,
#  '$ 100': 501,
#  '100 trillion': 2692,
#  'trillion https': 34205,
#  'win': 36860,
#  'probability': 27017,
#  'bullshit': 9792,
#  'man': 22235,
#  'saw': 29465,
#  'knew': 20985,
#  'isn': 20085,
#  'real': 27750,
#  ': win': 4106,
#  'man .': 22239,
#  '. i': 2121,
#  'i saw': 19278,
#  "that '": 32369,
#  's when': 29255,
#  'when i': 36456,
#  'i knew': 19250,
#  ', global': 1261,
#  'warming isn': 35716,
#  "isn '": 20086,
#  't real': 31919,
#  'washingtonpost': 35957,
#  'alaskan': 7106,
#  'tundra': 34498,
#  'filling': 16091,
#  'atmosphere': 8327,
#  'worsening': 37296,
#  '@ washingtonpost': 5753,
#  'washingtonpost :': 35958,
#  'atmosphere with': 8330,
#  'dioxide ,': 13842,
#  ', worsening': 1611,
#  'sunlorrie': 31640,
#  'indian': 19702,
#  'environmentalist': 15075,
#  'calls': 10141,
#  'dicaprio': 13756,
#  'his': 18670,
#  'own': 25703,
#  'documentary': 14096,
#  'ã': 38056,
#  ': from': 3534,
#  'from @': 16798,
#  '@ sunlorrie': 5619,
#  'sunlorrie :': 31641,
#  'calls out': 10149,
#  'his own': 18696,
#  'documentary on': 14105,
#  '. ã': 2377,
#  'ã ¢': 38057,
#  'realdonaldtrump': 27813,
#  'tax': 32092,
#  'globalist': 17360,
#  'idea': 19363,
#  'enslave': 15006,
#  'population': 26681,
#  'whole': 36635,
#  'reason': 27915,
#  'propagating': 27167,
#  ...}

# %% [markdown]
# ## Splitting the training data into a training and validation set

# %%
X_train,X_val,y_train,y_val = train_test_split(X_vectorized,y,test_size=0.20,shuffle=True, stratify=y, random_state=25)

# %% [markdown]
# ## Training the model and evaluating using the validation set

# %%
#rfc = RandomForestClassifier()
#rfc.fit(X_train, y_train)
#rfc_pred = rfc.predict(X_val)

# %%
lsvc = LinearSVC()
lsvc.fit(X_train, y_train)
lsvc_pred = lsvc.predict(X_val)

# %% [markdown]
# ## Checking the performance of our model on the validation set

# %%
f1_score(y_val, lsvc_pred, average="macro")
# Out:
# 0.6749640876116144

# %%
from sklearn import metrics

print(metrics.classification_report(y_val, lsvc_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.75      0.46      0.57       259
#            0       0.62      0.42      0.50       471
#            1       0.78      0.88      0.83      1706
#            2       0.78      0.83      0.81       728
#
#     accuracy                           0.77      3164
#    macro avg       0.73      0.65      0.67      3164
# weighted avg       0.76      0.77      0.75      3164

# %% [markdown]
# ## Getting our test set ready

# %%
testx = test['message']
test_vect = vectorizer.transform(testx)

# %% [markdown]
# ## Making predictions on the test set and adding a sentiment column to our original test df

# %%
y_pred = lsvc.predict(test_vect)

# %%
test['sentiment'] = y_pred

# %%
test.head()
# Out:
#                                              message  tweetid  sentiment
# 0  Europe will now be looking to China to make su...   169760          2
# 1  Combine this with the polling of staffers re c...    35326          1
# 2  The scary, unimpeachable evidence that climate...   224985          1
# 3  @Karoli @morgfair @OsborneInk @dailykos \nPuti...   476263          1
# 4  RT @FakeWillMoore: 'Female orgasms cause globa...   872928          0

# %% [markdown]
# ## Creating an output csv for submission

# %%
test[['tweetid','sentiment']].to_csv('testsubmission_8.csv', index=False)
